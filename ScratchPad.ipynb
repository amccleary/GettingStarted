# %% [markdown]
# <a href="https://colab.research.google.com/github/amccleary/GettingStarted/blob/master/ScratchPad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
purchfile = files.upload()

# %%
import pandas as pd
purchases = pd.read_csv('/content/PurchaseRequisitions 230405-103653.csv')
#purchases['Total Gross Amt/Base'].sum()
#purchases['Total Net Amt/Base'].max()
purchases['Total Gross Amt/Base'].cumsum().plot()
# Out:
# <Axes: >
